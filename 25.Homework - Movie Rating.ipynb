# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'F:\\Software\\Python Workspace\\Python Programming Course'

# %%
os.chdir('F:\\Software\\Python Workspace\\Python Programming Course\\data')

# %%
os.getcwd()
# Out:
# 'F:\\Software\\Python Workspace\\Python Programming Course\\data'

# %%
movies = pd.read_csv("Section6-Homework-Data.csv",encoding = 'utf-8')

# %%
movies = pd.read_csv("homework6.csv",encoding = 'ISO-8859-1')

# %%
movies.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
len(movies)
# Out:
# 608

# %%
movies.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
movies.columns=['DayOfWeek','Director','Genre',
                'MovieTitle','ReleaseDate','Studio',
                'AdjustedGross_Mill','Budget_Mill',
                'Gross_Mill','IMDB_Rating','MovieLens_Rating',
                'Overseas_Mill','Overseas_Per','Profit_Mill','Profit_Per',
                'Runtime_Min','US_Mill','Gross_Per_US',]

# %%
movies.head()
# Out:
#   DayOfWeek                 Director   Genre         MovieTitle ReleaseDate  \
# 0    Friday                Brad Bird  action       Tomorrowland  22/05/2015
# 1    Friday              Scott Waugh  action     Need for Speed  14/03/2014
# 2    Friday           Patrick Hughes  action  The Expendables 3  15/08/2014
# 3    Friday  Phil Lord, Chris Miller  comedy     21 Jump Street  16/03/2012
# 4    Friday          Roland Emmerich  action   White House Down  28/06/2013
#
#                 Studio AdjustedGross_Mill  Budget_Mill Gross_Mill  \
# 0  Buena Vista Studios              202.1        170.0      202.1
# 1  Buena Vista Studios              204.2         66.0      203.3
# 2            Lionsgate              207.1        100.0      206.2
# 3                 Sony              208.8         42.0      201.6
# 4                 Sony              209.7        150.0      205.4
#
#    IMDB_Rating  MovieLens_Rating Overseas_Mill  Overseas_Per Profit_Mill  \
# ...

# %%
movies[movies.IMDB_Rating>8]
# Out:
#      DayOfWeek                                   Director      Genre  \
# 11      Friday                              Morten Tyldum  biography
# 23   Wednesday                                Tate Taylor      drama
# 74      Friday                                Pete Docter  animation
# 85   Wednesday                             Clint Eastwood      drama
# 110     Friday                             Hayao Miyazaki  animation
# 131     Friday                             Clint Eastwood      drama
# 160     Friday                            Martin Scorsese      drama
# 169  Wednesday                                 Mel Gibson     action
# 178     Friday                            Roberto Benigni      drama
# 179     Friday                               Gus Van Sant      drama
# 186  Wednesday                             Jonathan Demme      drama
# 188     Friday                            Martin Scorsese   thriller
# 193     Friday                          Quentin Tarantino      crime
# ...

# %%
movies.Genre.cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-1de508ae4d85> in <module>()
# ----> 1 movies.Genre.cat.categories
#
# F:\Software\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# F:\Software\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     130             # we're accessing the attribute of the class, i.e., Dataset.geo
#     131             return self._accessor
# --> 132         accessor_obj = self._accessor(obj)
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# DayOfWeek             608 non-null object
# Director              608 non-null object
# Genre                 608 non-null object
# MovieTitle            608 non-null object
# ReleaseDate           608 non-null object
# Studio                608 non-null object
# AdjustedGross_Mill    608 non-null object
# Budget_Mill           608 non-null float64
# Gross_Mill            608 non-null object
# IMDB_Rating           608 non-null float64
# MovieLens_Rating      608 non-null float64
# Overseas_Mill         608 non-null object
# Overseas_Per          608 non-null float64
# Profit_Mill           608 non-null object
# Profit_Per            608 non-null float64
# Runtime_Min           608 non-null int64
# US_Mill               608 non-null float64
# Gross_Per_US          608 non-null float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 85.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['action', 'adventure', 'animation', 'biography', 'comedy', 'crime',
#        'documentary', 'drama', 'fantasy', 'horror', 'musical', 'mystery',
#        'romance', 'sci-fi', 'thriller'],
#       dtype='object')

# %%
type((movies.Genre=="action")) #| (movies.Genre=="comedy")
# Out:
# pandas.core.series.Series

# %%
mov1=movies[(movies.Genre=="action")|(movies.Genre=="comedy")|
      (movies.Genre=="adventure")|(movies.Genre=="animation")|
       (movies.Genre=="drama")]

# %%
mov1
# Out:
#      DayOfWeek                                           Director      Genre  \
# 0       Friday                                          Brad Bird     action
# 1       Friday                                        Scott Waugh     action
# 2       Friday                                     Patrick Hughes     action
# 3       Friday                            Phil Lord, Chris Miller     comedy
# 4       Friday                                    Roland Emmerich     action
# 5       Friday                                         David Ayer     action
# 6     Thursday                                       Rob Marshall  adventure
# 7       Friday                                    Daniel Espinosa     action
# 8       Friday                                         Gary Shore     action
# 10      Friday                                        Eric Brevig  animation
# 13      Friday                                        Seth Gordon     comedy
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# DayOfWeek             608 non-null object
# Director              608 non-null object
# Genre                 608 non-null category
# MovieTitle            608 non-null object
# ReleaseDate           608 non-null object
# Studio                608 non-null object
# AdjustedGross_Mill    608 non-null object
# Budget_Mill           608 non-null float64
# Gross_Mill            608 non-null object
# IMDB_Rating           608 non-null float64
# MovieLens_Rating      608 non-null float64
# Overseas_Mill         608 non-null object
# Overseas_Per          608 non-null float64
# Profit_Mill           608 non-null object
# Profit_Per            608 non-null float64
# Runtime_Min           608 non-null int64
# US_Mill               608 non-null float64
# Gross_Per_US          608 non-null float64
# dtypes: category(1), float64(7), int64(1), object(9)
# memory usage: 82.2+ KB

# %%
movies.Studio = movies.Studio.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# DayOfWeek             608 non-null object
# Director              608 non-null object
# Genre                 608 non-null category
# MovieTitle            608 non-null object
# ReleaseDate           608 non-null object
# Studio                608 non-null category
# AdjustedGross_Mill    608 non-null object
# Budget_Mill           608 non-null float64
# Gross_Mill            608 non-null object
# IMDB_Rating           608 non-null float64
# MovieLens_Rating      608 non-null float64
# Overseas_Mill         608 non-null object
# Overseas_Per          608 non-null float64
# Profit_Mill           608 non-null object
# Profit_Per            608 non-null float64
# Runtime_Min           608 non-null int64
# US_Mill               608 non-null float64
# Gross_Per_US          608 non-null float64
# dtypes: category(2), float64(7), int64(1), object(8)
# memory usage: 79.5+ KB

# %%
# Filter the dataframe by studio
mov2 = mov1[(mov1.Studio == 'Buena Vista Studios') | (mov1.Studio == 'Fox') | (mov1.Studio == 'Paramount Pictures') | (mov1.Studio == 'Sony') | (mov1.Studio == 'Universal') | (mov1.Studio == 'WB')]

# %%
mov2
# Out:
#      DayOfWeek                     Director      Genre  \
# 0       Friday                    Brad Bird     action
# 1       Friday                  Scott Waugh     action
# 3       Friday      Phil Lord, Chris Miller     comedy
# 4       Friday              Roland Emmerich     action
# 5       Friday                   David Ayer     action
# 6     Thursday                 Rob Marshall  adventure
# 7       Friday              Daniel Espinosa     action
# 8       Friday                   Gary Shore     action
# 10      Friday                  Eric Brevig  animation
# 14      Friday                  Ryan Murphy      drama
# 15      Friday              Paul Greengrass      drama
# 16      Friday               Hayao Miyazaki  animation
# 17      Friday           Jaume Collet-Serra     action
# 18      Friday           Jonathan Liebesman     action
# 19      Friday        Christopher McQuarrie     action
# 20      Friday                 Dennis Dugan     comedy
# ...

# %%
len(mov2)
# Out:
# 423

# %%
len(mov1)
# Out:
# 526

# %%
print (mov2.Genre.unique())
print (mov2.Studio.unique())
# Out:
# [action, comedy, adventure, animation, drama]
# Categories (5, object): [action, comedy, adventure, animation, drama]
# ['Buena Vista Studios' 'Sony' 'Universal' 'WB' 'Paramount Pictures' 'Fox']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Define the style
sns.set(style="darkgrid", palette="muted", color_codes=True)

# Plot the boxsplots
ax = sns.boxplot(data=mov2, x='Genre', y='Gross_Per_US', orient='v', color='lightgray', showfliers=False)
plt.setp(ax.artists, alpha=0.5)

# Add in points to show each observation
sns.stripplot(x='Genre', y='Gross_Per_US', data=mov2, jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross % US',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
